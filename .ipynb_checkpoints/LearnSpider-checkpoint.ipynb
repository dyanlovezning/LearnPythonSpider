# %%
import requests

# %%
my_headers=["Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36",
"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36",
"Mozilla/5.0 (Windows NT 6.1; WOW64; rv:30.0) Gecko/20100101 Firefox/30.0"
"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_2) AppleWebKit/537.75.14 (KHTML, like Gecko) Version/7.0.3 Safari/537.75.14",
"Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; Win64; x64; Trident/6.0)"]

# %%
headers = {'Accept': 'text/html, application/xhtml+xml, image/jxr, */*',
               'Accept - Encoding':'gzip, deflate',
               'Accept-Language':'zh-Hans-CN, zh-Hans; q=0.5',
               'Connection':'Keep-Alive',
               'Host':'zhannei.baidu.com',
               'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/52.0.2743.116 Safari/537.36 Edge/15.15063'}

# %%
headers2 = {'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
'Accept-Encoding': 'gzip, deflate, br',
'Accept-Language': 'zh-CN,zh;q=0.9',
'Cache-Control': 'max-age=0',
'Connection': 'keep-alive',
'Cookie': '__ckguid=IuEEba1RjiUf55iLU5Xg55; Hm_lvt_9b7ac3d38f30fe89ff0b8a0546904e58=1543826000; PHPSESSID=e431b98a4ab3257e99da3d462a819ac2; device_id=202861445015438260017578504e8d4de6dc9eada1f9c14f7dd9b66c09; zdm_qd=%7B%22referrer%22%3A%22https%3A%2F%2Fwww.baidu.com%2Flink%3Furl%3DsbPCVm1LFQYr84j3ttO8kkW9O0Zvk7EgDnoPT6gShqq%26wd%3D%26eqid%3Dcd36096a0000ece5000000065c04ea48%22%7D; _ga=GA1.2.1226656195.1543826000; _gid=GA1.2.1200527430.1543826000; __jsluid=cb4bd6ecdaa3862b20c98ebb2b23da66; Hm_lpvt_9b7ac3d38f30fe89ff0b8a0546904e58=1543826001',
'Host': 'm.smzdm.com',
'Upgrade-Insecure-Requests': '1',
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/70.0.3538.102 Safari/537.36'}

# %%
url = "https://m.smzdm.com/"

html = requests.get(url=url,headers=headers2)

print(html.status_code)
print(html.text)
# Out:
# 200
# <!DOCTYPE html>
# <html>
# <head>
#
#     <meta charset="UTF-8">
#     <meta content="yes" name="apple-mobile-web-app-capable">
#     <meta content="telephone=no,email=no" name="format-detection">
#
#     <meta name="applicable-device" content="mobile">
#     <meta http-equiv="Cache-Control" content="no-transform" />
#     <meta http-equiv="Cache-Control" content="no-siteapp" />
#     <link rel="manifest" href="//m.smzdm.com/manifest.json" />
#
#     <link href="http://res.smzdm.com/app/v1.0/dist/img/embed/icon114-114.png" rel="apple-touch-icon-precomposed">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0">
#
#
#     <!--header_v2-->
#
#     <link href="//res.smzdm.com/mobile/wap_v2/dist/css/commons.3d05e90.css" rel="stylesheet">
#     <link href="//res.smzdm.com/mobile/wap_v2/dist/css/index/index.3d05e90.css" rel="stylesheet">
#
#     <!-- SEO 相关 -->
#     <script type="application/ld+json">
#     {
#         "@context": "http://schema.org",
#         "@type": "Organization",
#         "url": "https://www.smzdm.com",
#         "logo": "https://res.smzdm.com/images/2018/05/logo.png"
#     }
#     </script>
#             <title>什么值得买 | 高性价比网购产品推荐_国内促销_海淘特价_商家优惠券</title>
#         <meta name="description" content="什么值得买是一家消费门户网站，实时推送优质的网购优惠信息，真实的原创购物攻略，力求成为消费者心目中的“品质消费第一站”，内容涉及3C家电、家居生活、时尚运动、海淘、旅游、汽车、信用卡等多个领域，网购就上什么值得买，让您的消费更值！" />
#         <meta name="keywords" content="什么值得买,值得买,国内,海淘,网购,特价,打折,促销,优惠券,网友点评" />
#
#     <script type="text/javascript">
#         // var browse_edition = $.cookie("browse_edition");
#         // if ("web" == browse_edition) {
#
#         // }
#         var googletag = googletag || {};
#         googletag.cmd = googletag.cmd || [];
#         (function() {
#             var gads = document.createElement('script');
#             gads.async = true;
#             gads.type = 'text/javascript';
#             var useSSL = 'https:' == document.location.protocol;
#             gads.src = (useSSL ? 'https:' : 'http:') +
#                 '//www.googletagservices.com/tag/js/gpt.js';
#             var node = document.getElementsByTagName('script')[0];
#             node.parentNode.insertBefore(gads, node);
#         })();
#     </script>
#
#
#
#                         <link rel="canonical" href="https://www.smzdm.com/"/>
#
#
# </head>
#
# <!-- gtm 相关 -->
#
# <noscript><iframe src="//www.googletagmanager.com/ns.html?id=GTM-T48BDF"
#                   height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
#
# <!-- Google Tag Manager -->
# <script>
#     window.onload = function () {
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=w.location.search.match(/55gtmpreview=1/)?
#             '//www.googletagmanager.com/gtm.js?id='+i+dl:'https://res-ga.smzdm.com/gtm.js?id=' + i + dl;f.parentNode.insertBefore(j,f);
#         })(window,document,'script','dataLayer','GTM-T48BDF');
#     }
# </script>
#
# <body>
#
#
#     <!-- 从百度过来时显示的banner -->
#         <div class="top-applink">
#         <div class="swiper-wrapper">
#             <div class="swiper-slide">
#                 <a href="javascript:;" class="btn-banner-close J_toplink_close">
#                     <i class="icon-close"></i>
#                 </a>
#                 <div class="app-info">
#                     <span class="app-logo"><img src="https://res.smzdm.com/mobile/wap/dist/img/logo_app.png" alt="什么值得买app"></span>
#                     <div class="app-intro">更多超值优惠，尽在值得买好价频道<br>快去下载App查看吧</div>
#                 </div>
#                                     <a onclick="dataLayer.push({'event':'WAP站百度浮层','tag':'shouye','name':'列表页'})" class="btn-app-open J_ota" href="//m.smzdm.com/app/?is_detail=1" target="_blank">打开</a>
#                             </div>
#         </div>
#     </div>
#     <header class="head_banner header-top fixed" id="J_header_top">
#     <div class="header-in">
#                     <!-- 顶部白色logo -->
#             <div class="header-white">
#                 <div class="logo-img">
#                     <div id="logo">
#                         <a href="https://m.smzdm.com/"><img src="//res.smzdm.com/mobile/wap_v2/dist/img/embed/logo.png"></a>
#                     </div>
#                 </div>
#
#                 <div class="logo-search">
#                     <i class="icon-search zm-icon-search-o"></i>
#                     <input type="text" name="search" placeholder="搜索分类/品牌/商品" id="J_enter_search">
#                     <img src="//res.smzdm.com/mobile/wap_v2/dist/img/embed/delete.png" class="icon-cancel" id="J_icon_cancel">
#                 </div>
#
#                 <div class="logo-download"><a target="_blank" class="J_ota" href="//m.smzdm.com/app/?is_detail=" onclick="dataLayer.push({'event':'WAP站banner下载浮层','tag':'home_list','name':'列表页','type':'顶部导航栏'})">下载</a></div>
#             </div>
#                         <div class="header-tab">
#             <div class="header-inner">
#                 <div class="channel-list">
#                     <ul >
#                                             <li><a href="https://m.smzdm.com/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'首页'})"
#                                 class="cur-tab">首页</a></li>
#                                             <li><a href="https://m.smzdm.com/youhui/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'国内好价'})"
#                                 >国内好价</a></li>
#                                             <li><a href="https://haitao.m.smzdm.com/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'海淘好价'})"
#                                 >海淘好价</a></li>
#                                             <li><a href="https://faxian.m.smzdm.com/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'全部好价'})"
#                                 >全部好价</a></li>
#                                             <li><a href="https://post.m.smzdm.com/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'好文'})"
#                                 >好文</a></li>
#                                             <li><a href="https://h5.smzdm.com/user/coupon/coupon_list/?f=wap"
#                                onclick="dataLayer.push({'event':'2300001','tab':'优惠券'})"
#                                 >优惠券</a></li>
#                                             <li><a href="https://m.smzdm.com/tag/白菜党/faxian/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'白菜党'})"
#                                 >白菜党</a></li>
#                                             <li><a href="https://m.smzdm.com/list/"
#                                onclick="dataLayer.push({'event':'2300001','tab':'好物榜单'})"
#                                 >好物榜单</a></li>
#                                         </ul>
#                 </div>
#                 <div class="all-tabs">
#                     <a href="https://m.smzdm.com/fenlei/">
#                         <i class="icon-tab-list"></i>
#                         <span>分类</span>
#                     </a>
#                 </div>
#             </div>
#         </div>
#             </div>
# </header>
#
# <div id="ch-mirrors"></div>
#
# <input type="hidden" id="search_top_category" value="">
#
# <!--slider 轮播图-->
# <!-- Slider main container -->
# <div class="swiper-container">
#     <!-- Additional required wrapper -->
#     <div class="swiper-wrapper">
#         <!-- Slides -->
#                             <div class="swiper-slide"><a onclick="dataLayer.push({'event':'WAP首页_轮播图','文章标题':'球鞋发黄怎么办？篇二：终极去黄，氧化还原法','位置':'0'});" class="pic" href="https://post.smzdm.com/p/apzepwxx/"><img src="https://tp-eimg.smzdm.com/201812/04/5c05ea826dbac9058.png"></a></div>
#
#                     <div class="swiper-slide"><a onclick="dataLayer.push({'event':'WAP首页_轮播图','文章标题':'鼠标微动评测 90%都是干货','位置':'0'});" class="pic" href="https://post.smzdm.com/p/adwlxlrp/"><img src="https://tp-eimg.smzdm.com/201812/04/5c06190ba32152389.png"></a></div>
#
#                     <div class="swiper-slide"><a onclick="dataLayer.push({'event':'WAP首页_轮播图','文章标题':'4日0点、促销活动： 亚马逊中国 欧洲厨卫专场 满9999元减1000元，满7999元减700元 ','位置':'0'});" class="pic" href="https://www.smzdm.com/p/11805375/"><img src="https://tp-eimg.smzdm.com/201812/03/5c050ae01780e473.jpg"></a></div>
#
#                     <div class="swiper-slide"><a onclick="dataLayer.push({'event':'WAP首页_轮播图','文章标题':'换工作城市后 社保是否转移误区','位置':'0'});" class="pic" href="https://post.smzdm.com/p/adwl5erp/"><img src="https://tp-eimg.smzdm.com/201812/04/5c061aad468c42709.png"></a></div>
#
#                     <div class="swiper-slide"><a onclick="dataLayer.push({'event':'WAP首页_轮播图','文章标题':'PPT总是平淡无奇？10秒钟就能做出的3D立体PPT了解一下','位置':'0'});" class="pic" href="https://post.smzdm.com/p/adwl3zdp/"><img src="https://tp-eimg.smzdm.com/201812/03/5c04f538401079636.png"></a></div>
#
#                     <div class="swiper-slide"><a onclick="dataLayer.push({'event':'WAP首页_轮播图','文章标题':'The Game Awards 2018大奖年度游戏提名榜','位置':'0'});" class="pic" href="https://www.smzdm.com/list/70050348/"><img src="https://tp-eimg.smzdm.com/201812/04/5c0619d747e4b420.png"></a></div>
#                                 <div class="zm-card-title">Nan ji ren 南极人 小白鞋清洁剂 100ml*2瓶 送清洁巾</div>
#                                 <div class="card-price">
#                                     5.9元包邮(需用券)                                </div>
#                                 <div class="zm-card-actions">
#                                     <div class="zm-card-actions-left">
#                                     <span>
#                             <span class="card-mall">天猫精选</span>
#                                     <span>14:14</span>
#                                     </span>
#                                     </div>
#                                     <div class="zm-card-actions-right">
#                                     <span class="icon-group">
#                             <i class="zm-icon-comments-o"></i>0                        </span>
#                                         <span class="icon-group">
#                             <i class="zm-icon-zhi-char"></i>67%                        </span>
#                                     </div>
#                                 </div>
#                             </div>
#                         </div>
#                     </a>
#                 </li>
#                                          </ul>
#     <div class="loading" id="J_loading">
#         <img src="https://res.smzdm.com/activity/img/iphone_active/loading.gif">
#     </div>
#     <div class="pagination"><div class="prev"><a href="https://m.smzdm.com/p2/"><i class="zm-icon-arrow-left"></i></a></div><span>第3页</span><div class="next"><a href="https://m.smzdm.com/p4/"><i class="zm-icon-arrow-right"></i></a></div></div></div>
#
# <script type="x-tmpl-mushache" id="J_feed_template">
# {{#is_tad}}
# <li class="card-group-list J_ad_click" data-clicked="{{click_tracking_url}}" data-exposure="{{impression_tracking_url}}"  timesort="{{time_sort}}" >
#     <a href="{{ url }}" target="_blank" class="ad-link"  onclick="dataLayer.push({'event':'2290002', 'position':'{{position}}', 'type':'通栏模式'});">
#         <img src="{{ img }}" alt="{{ title }}">
#     </a>
#     {{#is_show_label}}
#     <span class="ad-span">
#         <span></span>
#         {{show_tag}}
#     </span>
#     {{/is_show_label}}
# </li>
# {{/is_tad}}
# {{#is_leftad}}
# <li class="card-group-list J_ad_click" data-clicked="{{click_tracking_url}}" data-exposure="{{impression_tracking_url}}"  timesort="{{time_sort}}" >
#     <a href="{{ url }}" target="_blank" onclick="dataLayer.push({'event':'2290002', 'position': '{{position}}', 'type': '一文一图'});">
#         <div class="zm-card">
#             <div class="zm-card-media">
#                 <img src="{{ img }}" alt="{{ title }}" />
#             </div>
#             <div class="zm-card-content">
#                 <div class="zm-card-title">{{title}}</div>
#                 <div class="card-price">
#                     {{subtitle}}
#                 </div>
#                 {{#is_show_label}}
#                 <div class="zm-card-actions">
#                     <div class="zm-card-actions-left">
#                         <span>
#                             <span class="card-mall">{{show_tag}}</span>
#                         </span>
#                     </div>
#                 </div>
#                 {{/is_show_label}}
#             </div>
#         </div>
#     </a>
# </li>
# {{/is_leftad}}
# {{#is_guonei}}
# <li class="card-group-list" timesort="{{timesort}}" articleid="{{ article_channel_id }}_{{ article_id }}">
#     <a href="{{ article_url }}" onclick="dataLayer.push({'event':'WAP首页_标题', 'pagetitle':'{{article_title}}'})">
#         <div class="zm-card">
#             <div class="zm-card-media">
#                 <img src="{{ article_pic }}" alt="{{ article_title }}" />
#                 <div class="card-label card-label-guonei">国内</div>
#             </div>
#             <div class="zm-card-content">
#                 <div class="zm-card-title">{{article_title}}</div>
#                 <div class="card-price">{{ article_price }}</div>
#                 <div class="zm-card-actions">
#                     <div class="zm-card-actions-left">
#                         <span>
#                             <span class="card-mall">{{ article_mall }}</span>
#                             <span>{{ article_format_date }}</span>
#                         </span>
#                     </div>
#                     <div class="zm-card-actions-right">
#                         <span class="icon-group">
#                             <i class="zm-icon-comments-o"></i>{{ article_comment }}
#                         </span>
#                         <span class="icon-group">
#                             <i class="zm-icon-zhi-char"></i>{{article_worthy}}
#                         </span>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </a>
# </li>
# {{/is_guonei}}
# {{#is_yuanchuang}}
# <li class="card-group-list" timesort="{{timesort}}" articleid="{{ article_channel_id }}_{{ article_id }}">
#     <a href="{{ article_url }}" onclick="dataLayer.push({'event':'WAP首页_标题', 'pagetitle':'{{article_title}}'})">
#         <div class="zm-card">
#             <div class="zm-card-media">
#                 <img src="{{ article_pic }}" alt="{{ article_title }}" />
#                 <div class="card-label card-label-yuanchuang">原创</div>
#             </div>
#             <div class="zm-card-content">
#                 <div class="zm-card-title">{{article_title}}</div>
#                 <div class="card-yuanchuang">
#                     {{tag_category}}
#                 </div>
#                 <div class="zm-card-actions">
#                     <div class="zm-card-actions-left">
#                         <span class="card-btm-user-info"><img src="{{article_referrals_avatar}}" alt="{{article_referrals}}">
#                         <span>{{article_referrals}}</span>
#                         </span>
#                     </div>
#                     <div class="zm-card-actions-right">
#                         <span class="icon-group">
#                             <i class="zm-icon-comments-o"></i>{{ article_comment }}
#                         </span>
#                         <span class="icon-group">
#                             <i class="zm-icon-star-o"></i>{{ article_collection }}
#                         </span>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </a>
# </li>
# {{/is_yuanchuang}}
# {{#is_zixun}}
# <li class="card-group-list" timesort="{{timesort}}" articleid="{{ article_channel_id }}_{{ article_id }}">
#     <a href="{{ article_url }}" onclick="dataLayer.push({'event':'WAP首页_标题', 'pagetitle':'{{article_title}}'})">
#         <div class="zm-card">
#             <div class="zm-card-media">
#                 <img src="{{ article_pic }}" alt="{{ article_title }}" />
#                 <div class="card-label card-label-zixun">资讯</div>
#             </div>
#             <div class="zm-card-content">
#                 <div class="zm-card-title">{{article_title}}</div>
#                 <div class="card-zixun">{{article_price}}</div>
#                 <div class="zm-card-actions">
#                     <div class="zm-card-actions-left">
#                         <span>
#                             <span class="card-mall">{{article_rzlx_name}}</span>
#                             <span>{{article_format_date}}</span>
#                         </span>
#                     </div>
#                     <div class="zm-card-actions-right">
#                         <span class="icon-group">
#                             <i class="zm-icon-comments-o"></i>{{ article_comment }}
#                         </span>
#                         <span class="icon-group">
#                             <i class="zm-icon-thumb-up-o"></i>{{article_love_count}}
#                         </span>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </a>
# </li>
# {{/is_zixun}}
# {{#is_haitao}}
# <li class="card-group-list" timesort="{{timesort}}" articleid="{{ article_channel_id }}_{{ article_id }}">
#     <a href="{{ article_url }}" onclick="dataLayer.push({'event':'WAP首页_标题', 'pagetitle':'{{article_title}}'})">
#         <div class="zm-card">
#             <div class="zm-card-media">
#                 <img src="{{ article_pic }}" alt="{{ article_title }}" />
#                 <div class="card-label card-label-haitao">海淘</div>
#             </div>
#             <div class="zm-card-content">
#                 <div class="zm-card-title">{{article_title}}</div>
#                 <div class="card-price">{{ article_price }}</div>
#                 <div class="zm-card-actions">
#                     <div class="zm-card-actions-left">
#                         <span>
#                             <span class="card-mall">{{ article_mall }}</span>
#                             <span>{{ article_format_date }}</span>
#                         </span>
#                     </div>
#                     <div class="zm-card-actions-right">
#                         <span class="icon-group">
#                             <i class="zm-icon-comments-o"></i>{{ article_comment }}
#                         </span>
#                         <span class="icon-group">
#                             <i class="zm-icon-zhi-char"></i>{{article_worthy}}
#                         </span>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </a>
# </li>
# {{/is_haitao}}
# {{#is_zhongce}}
# <li class="card-group-list" timesort="{{timesort}}" articleid="{{ article_channel_id }}_{{ article_id }}">
#     <a href="{{ article_url }}" onclick="dataLayer.push({'event':'WAP首页_标题', 'pagetitle':'{{article_title}}'})">
#         <div class="zm-card">
#             <div class="zm-card-media">
#                 <img src="{{ article_pic }}" alt="{{ article_title }}" />
#                 <div class="card-label card-label-zhongce">众测</div>
#             </div>
#             <div class="zm-card-content">
#                 <div class="zm-card-title">{{article_title}}</div>
#                 <div class="zm-card-actions">
#                     <div class="zm-card-actions-left">
#                         <span class="card-btm-user-info"><img src="{{article_referrals_avatar}}" alt="{{article_referrals}}">
#                         <span>{{article_referrals}}</span>
#                         </span>
#                     </div>
#                     <div class="zm-card-actions-right">
#                         <span class="icon-group">
#                             <i class="zm-icon-comments-o"></i>{{ article_comment }}
#                         </span>
#                         <span class="icon-group">
#                             <i class="zm-icon-star-o"></i>{{ article_collection }}
#                         </span>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </a>
# </li>
# {{/is_zhongce}}
# </script>
# <script>
#     /* if ('serviceWorker' in navigator) {
#         window.addEventListener('load', () => {
#             navigator.serviceWorker
#                 .register('./sw.js')
#                 .then(registration => {
#                     console.log('SW registered: ', registration);
#                 })
#                 .catch(registrationError => {
#                     console.log('SW registration failed: ', registrationError);
#                 });
#         });
#     } */
# </script>
#
# <div class="foot-banner">
#     <input type="hidden" id="J_from_share" value="">
#     <input type="hidden" id="J_ga_tag" value="home_list">
#     <input type="hidden" id="J_ga_name" value="列表页">
#     <input type="hidden" id="J_share_link" value="">
#     <input type="hidden" id="J_share_pic" value="http://y.zdmimg.com/201811/26/5bfb94908bf276996.png">
#
#     <div class="mode">
#         <div class="mode-touch">当前为触屏版</div>
#         <div class="mode-pc"><a href="//m.smzdm.com/switch_edition">切换到电脑版<em><img src="//res.smzdm.com/mobile/wap/dist/img/download_arrow.png"></em></a></div>
#     </div>
#     <!--foot-banner end-->
#     <div class="right-return-top">
#         <div class="return-top">
#             <img src="//res.smzdm.com/mobile/wap/dist/img/return_top.png">
#         </div>
#     </div>
# </div>
# <!-- 搜索浮层模板 -->
# <div class="search-cover" id="J_search_cover">
#
#     <!-- 搜索页头部搜索框 -->
#     <form action="//search.m.smzdm.com" method="get" class="search-header" id="J_search_form">
#
#         <i class="search-return zm-icon-arrow-left" id="J_search_close"></i>
#         <div class="search-input" id="J_search_sug">
#             <i class="icon-search zm-icon-search-o"></i>
#             <input type="text" name="s" placeholder="搜索分类/品牌/商品" id="J_search_input" >
#             <img src="//res.smzdm.com/mobile/wap_v2/dist/img/embed/delete.png" class="icon-cancel" id="J_search_clear">
#         </div>
#         <button type="submit" class="search-button" disabled="disabled" id="J_search_btn">搜索</button>
#
#     </form>
#
#     <div class="search-hot">
#         <div class="hot-title">热门搜索</div>
#         <ul class="hot-list">
#                     </ul>
#     </div>
# </div>
#
# <script type="text/javascript" src="//res.smzdm.com/mobile/wap_v2/dist/js/commons.3d05e90.js"></script>
# <script type="text/javascript" src="//res.smzdm.com/mobile/wap_v2/dist/js/index/index.3d05e90.js"></script>
#
# <div style="display:none">
#
#     <script>
#         var _bdhmProtocol = (("https:" == document.location.protocol) ? " https://" : " http://");
#         document.write(unescape("%3Cscript src='" + _bdhmProtocol + "hm.baidu.com/h.js%3F9b7ac3d38f30fe89ff0b8a0546904e58' type='text/javascript'%3E%3C/script%3E"));
#     </script>
#
# </div>
# </body>
#
# </html>

# %%
from lxml import etree

# %%
selector = etree.HTML(html.text)
tmp = selector.xpath('//*[@class="zm-card-title"]/text()')
price = selector.xpath('//div[@class="card-price"]/text()')

type(tmp)
for (t,p) in zip(tmp,price):
    print(t + "              " + p.strip())
# Out:
# 历史低价：MEIZU 魅族 16th Plus 智能手机 6GB+128GB 远山白              2848元包邮（需用券）
# 12日0点、双12预售：SKIP HOP 儿童防走失背包              89元包邮
# 12日0点、双12预告：Grohe 高仪 23554001 斯达单把手面盆龙头              746元包邮（需用券）
# ROCKETDOG Camilla 女士靴子 *2件              £78.56包邮（约¥690，合¥345/件）
# moony 尤妮佳 早产儿纸尿裤 30片 *3件              81.9元（合27.3元/件）
# 视觉空间 新年装饰贴纸 24款可选              3.99元包邮（需用券）
# 值友专享：Oissie 奥伊西 婴儿夹棉连体衣              59元包邮（需用券）
# 安美安 6叶吊扇  46*18cm              9.9元包邮（需用券）
# 20点开始：Haier  海尔 HSW-PF2 前置过滤器              379元包邮
# KFC 肯德基 欢享套餐 Y81              126元
# 欧生雅 折叠式修眉刀 3支装              5.8元包邮（需用券）
# DECATHLON 迪卡侬 500系列 幼童运动衫              29.9元包邮
# 双12预售：TCL 55Q960C 55英寸 4K 量子点 曲面液晶电视              4299元包邮（定金100元）
# 双12预售：wonderbra WBW6F92T 女士无钢圈精油水袋文胸套装              79元（需定金17元）
# 壹念 空气清新剂 芳香水晶球 280g              5.9元包邮(需用券)
# rikang 日康 婴儿浴盆 RK-3626 *3件 +凑单品              149.9元包邮（合49.9元/件）
# 7日0点：Roborock 石头 S55（礼盒版） 扫拖一体机              2449元包邮
# 东风 嘉实多 全护 汽机油全合成润滑油 5W-30 SN级 4L              99元（包邮）
# Yandex 男士商务休闲手提包              86元包邮（需用码）
# Nan ji ren 南极人 小白鞋清洁剂 100ml*2瓶 送清洁巾              5.9元包邮(需用券)

# %%
tmp = selector.xpath('//li[@class="card-group-list"]/a/@href')
content = selector.xpath('//li[@class="card-group-list"]/a/div/div/img/@alt')
price = selector.xpath('//li[@class="card-group-list"]/a/div/div/div[@class="card-price"]/text()')

print(type(tmp))
for (c,p,t) in zip(content,price,tmp):
    print(c+"\t"+p.strip()+"\t"+t)
# Out:
# <class 'list'>
# 历史低价：MEIZU 魅族 16th Plus 智能手机 6GB+128GB 远山白	2848元包邮（需用券）	https://m.smzdm.com/p/11812687/
# 12日0点、双12预售：SKIP HOP 儿童防走失背包	89元包邮	https://m.smzdm.com/p/11816978/
# 12日0点、双12预告：Grohe 高仪 23554001 斯达单把手面盆龙头	746元包邮（需用券）	https://m.smzdm.com/p/11785700/
# ROCKETDOG Camilla 女士靴子 *2件	£78.56包邮（约¥690，合¥345/件）	https://m.smzdm.com/p/11813552/
# moony 尤妮佳 早产儿纸尿裤 30片 *3件	81.9元（合27.3元/件）	https://m.smzdm.com/p/11816117/
# 视觉空间 新年装饰贴纸 24款可选	3.99元包邮（需用券）	https://m.smzdm.com/p/11811621/
# 值友专享：Oissie 奥伊西 婴儿夹棉连体衣	59元包邮（需用券）	https://m.smzdm.com/p/11814591/
# 安美安 6叶吊扇  46*18cm	9.9元包邮（需用券）	https://m.smzdm.com/p/11816722/
# 20点开始：Haier  海尔 HSW-PF2 前置过滤器	379元包邮	https://m.smzdm.com/p/11805444/
# KFC 肯德基 欢享套餐 Y81	126元	https://m.smzdm.com/p/11817358/
# 欧生雅 折叠式修眉刀 3支装	5.8元包邮（需用券）	https://m.smzdm.com/p/11790770/
# DECATHLON 迪卡侬 500系列 幼童运动衫	29.9元包邮	https://m.smzdm.com/p/11816161/
# 双12预售：TCL 55Q960C 55英寸 4K 量子点 曲面液晶电视	4299元包邮（定金100元）	https://m.smzdm.com/p/11814604/
# 双12预售：wonderbra WBW6F92T 女士无钢圈精油水袋文胸套装	79元（需定金17元）	https://m.smzdm.com/p/11816556/
# 壹念 空气清新剂 芳香水晶球 280g	5.9元包邮(需用券)	https://m.smzdm.com/p/11817554/
# rikang 日康 婴儿浴盆 RK-3626 *3件 +凑单品	149.9元包邮（合49.9元/件）	https://m.smzdm.com/p/11816472/
# 7日0点：Roborock 石头 S55（礼盒版） 扫拖一体机	2449元包邮	https://m.smzdm.com/p/11808398/
# 东风 嘉实多 全护 汽机油全合成润滑油 5W-30 SN级 4L	99元（包邮）	https://m.smzdm.com/p/11817042/
# Yandex 男士商务休闲手提包	86元包邮（需用码）	https://m.smzdm.com/p/11812573/
# Nan ji ren 南极人 小白鞋清洁剂 100ml*2瓶 送清洁巾	5.9元包邮(需用券)	https://m.smzdm.com/p/11817556/

# %%
html1 = '''
<!-- hello.html -->
<div>
    <ul>
         <li class="item-0"><a href="link1.html">first item</a></li>
         <li class="item-1"><a href="link2.html">second item</a></li>
         <li class="item-inactive"><a href="link3.html"><span class="bold">third item</span></a></li>
         <li class="item-1"><a href="link4.html">fourth item</a></li>
         <li class="item-0"><a href="www.baidu.com">fifth item</a></li>
     </ul>
 </div>
'''

from lxml import etree

html = etree.HTML(html1)
    
result = html.xpath('//li')
print(result)  # 打印<li>标签的元素集合
# Out:
# [<Element li at 0x1792c1fb988>, <Element li at 0x1792c237448>, <Element li at 0x1792c237488>, <Element li at 0x1792c2374c8>, <Element li at 0x1792c237508>]

# %%
 result = html.xpath('//li/a[@href="www.baidu.com"]/text()')

 print(result)
# Out:
# ['fifth item']

# %%
print(result[0].text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-3eb37769b143> in <module>
# ----> 1 print(result[0].text)
#
# AttributeError: 'lxml.etree._ElementUnicodeResult' object has no attribute 'text'
